# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharanidharan-M/Bharanidharan-M-Restaurant-food-Analysis-using-ML/blob/main/Restaurant_food_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('/content/Restaurant.xlsx')

# %%
data.head()
# Out:
#        DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0  01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 1  01.10.23  23.40         174  OMLETTE       2.0  18.0       36.0   108.0
# 2  01.10.23  23.36         173     DOSA       3.0  20.0       60.0     NaN
# 3  01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 4  01.10.23  23.36         173   KALAKI       1.0  15.0       15.0   111.0
#
#    DAY
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
data.isnull().sum()
# Out:
# DATE            0
# TIME            0
# INVOICE_NO      0
# ITEM            0
# QUANTITY        2
# RATE            1
# SUB_TOTAL       1
# AMOUNT        307
# DAY             0
# dtype: int64

# %%
x= data[data["DATE"]=="01.10.23"]
display(x)
# Out:
#          DATE   TIME  INVOICE_NO              ITEM  QUANTITY   RATE  \
# 0    01.10.23  23.40         174           PAROTTA       4.0   18.0
# 1    01.10.23  23.40         174           OMLETTE       2.0   18.0
# 2    01.10.23  23.36         173              DOSA       3.0   20.0
# 3    01.10.23  23.36         173           PAROTTA       2.0   18.0
# 4    01.10.23  23.36         173            KALAKI       1.0   15.0
# ..        ...    ...         ...               ...       ...    ...
# 254  01.10.23  12.36           7            KALAKI       1.0   15.0
# 255  01.10.23  12.15           5           PAROTTA       2.0   18.0
# 256  01.10.23  12.15           4  CHICKEN BIRIYANI       2.0  110.0
# 257  01.10.23  12.15           4    CHILLI CHICKEN       1.0  100.0
# 258  01.10.23  12.08           3         CHAPPATHI       3.0   18.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 0         72.0     NaN    1
# 1         36.0   108.0    1
# 2         60.0     NaN    1
# 3         36.0     NaN    1
# ...

# %%
b=data[data["INVOICE_NO"]==117]
display(b)
# Out:
#           DATE   TIME  INVOICE_NO                ITEM  QUANTITY   RATE  \
# 80    01.10.23  20.29         117          GHEE ROAST       2.0   50.0
# 81    01.10.23  20.29         117           EGG ROAST       2.0   50.0
# 82    01.10.23  20.29         117     CHICKEN NOODLES       1.0  100.0
# 83    01.10.23  20.29         117      CHILLI CHICKEN       1.0  100.0
# 84    01.10.23  20.29         117         COOL DRINKS       2.0   15.0
# 491  2.10.2250  21.00         117   SCHEZWAN EGG RICE       1.0   95.0
# 492  2.10.2251  21.00         117  CHICKEN FRIED RICE       1.0  100.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 80       100.0     NaN    1
# 81       100.0     NaN    1
# 82       100.0     NaN    1
# 83       100.0     NaN    1
# 84        30.0   430.0    1
# 491       95.0     NaN    2
# 492      100.0   195.0    2

# %%
b["AMOUNT"].mean()
# Out:
# np.float64(312.5)

# %%
b["AMOUNT"].sum()
# Out:
# np.float64(625.0)

# %%
data.sort_values(by="AMOUNT",ascending=False)
# Out:
#           DATE   TIME  INVOICE_NO             ITEM  QUANTITY   RATE  \
# 19    01.10.23  15.34          68          PAROTTA      44.0   18.0
# 418  2.10.2177  22.12         159        GOLI SODA       3.0   30.0
# 433  2.10.2192  22.06         155  CHICKEN PAROTTA       1.0   90.0
# 475  2.10.2234  21.11         126     WATER BOTTLE       1.0   20.0
# 172   01.10.23  15.25          66      FISH CHILLI       1.0  110.0
# ..         ...    ...         ...              ...       ...    ...
# 518  2.10.2277  20.29          97        CHAPPATHI       4.0   18.0
# 520  2.10.2279  19.51          78        CHAPPATHI       3.0   18.0
# 522  2.10.2281  22.38         168             DOSA       3.0   20.0
# 523  2.10.2282  22.38         168          PAROTTA       4.0   18.0
# 528  2.10.2287  21.53         147   BUTTER CHICKEN       1.0  130.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 19       792.0   792.0    1
# 418       90.0   728.0    2
# 433       90.0   665.0    2
# 475       20.0   655.0    2
# ...

# %%
h=data.groupby("ITEM")["QUANTITY"].sum().sort_values(ascending=False).head()
display(h)
# Out:
# ITEM
# PAROTTA             297.0
# DOSA                108.0
# CHAPPATHI            50.0
# KALAKI               49.0
# CHICKEN BIRIYANI     46.0
# Name: QUANTITY, dtype: float64

# %%
sns.barplot(h)
# Out:
# <Axes: xlabel='ITEM', ylabel='QUANTITY'>

# %%
x=h.index
y=h.values
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
h=data.groupby("ITEM")["SUB_TOTAL"].sum().sort_values(ascending=False).head()
display(h)
# Out:
# ITEM
# PAROTTA             5346.0
# CHICKEN BIRIYANI    5060.0
# MUTTON BIRIYANI     2550.0
# PLAIN BIRIYANI      2240.0
# DOSA                2160.0
# Name: SUB_TOTAL, dtype: float64

# %%
sns.barplot(h)
# Out:
# <Axes: xlabel='ITEM', ylabel='SUB_TOTAL'>

# %%
x=h.index
y=h.values
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
h=data.groupby("INVOICE_NO")["AMOUNT"].sum().sort_values(ascending=False).head()
display(h)
# Out:
# INVOICE_NO
# 63     941.0
# 68     892.0
# 66     835.0
# 58     808.0
# 159    768.0
# Name: AMOUNT, dtype: float64

# %%
sns.barplot(h)
# Out:
# <Axes: xlabel='INVOICE_NO', ylabel='AMOUNT'>

# %%
x=data[data["DATE"]=='01.10.23']
x[(x["TIME"]>=18.00) & (x["TIME"]<=21.00)]
x[x["ITEM"]=="PAROTTA"]
display(x)
# Out:
#          DATE   TIME  INVOICE_NO              ITEM  QUANTITY   RATE  \
# 0    01.10.23  23.40         174           PAROTTA       4.0   18.0
# 1    01.10.23  23.40         174           OMLETTE       2.0   18.0
# 2    01.10.23  23.36         173              DOSA       3.0   20.0
# 3    01.10.23  23.36         173           PAROTTA       2.0   18.0
# 4    01.10.23  23.36         173            KALAKI       1.0   15.0
# ..        ...    ...         ...               ...       ...    ...
# 254  01.10.23  12.36           7            KALAKI       1.0   15.0
# 255  01.10.23  12.15           5           PAROTTA       2.0   18.0
# 256  01.10.23  12.15           4  CHICKEN BIRIYANI       2.0  110.0
# 257  01.10.23  12.15           4    CHILLI CHICKEN       1.0  100.0
# 258  01.10.23  12.08           3         CHAPPATHI       3.0   18.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 0         72.0     NaN    1
# 1         36.0   108.0    1
# 2         60.0     NaN    1
# 3         36.0     NaN    1
# ...
